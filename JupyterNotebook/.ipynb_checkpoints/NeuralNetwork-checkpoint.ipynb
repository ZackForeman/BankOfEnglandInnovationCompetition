# %%
# Imports // use https://pub.towardsai.net/predict-the-stock-trend-using-deep-learning-5a4b7df1d152

import tensorflow as tf
import pandas as pd
from tensorflow import keras
import sklearn
from sklearn.model_selection import train_test_split

print("Imports Completed")
# Out:
# Imports Completed

# %%
# Import Dataset and Split
inputs = pd.read_csv("C:/Users/tiafo/Desktop/BankOfEnglandInnovaitonCompetition/JupyterNotebook/inputs.csv").to_numpy()
outputs = pd.read_csv("C:/Users/tiafo/Desktop/BankOfEnglandInnovaitonCompetition/JupyterNotebook/outputs.csv").to_numpy()

X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.8)

print("Datasets Loaded and table split")
# Out:
# Datasets Loaded and table split

# %%
# Create Model
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(5)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, 'softmax')
])

# %%
model.compile(optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 1s 7ms/step - loss: 18063.6230 - accuracy: 0.0000e+00
# Epoch 2/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 15207.5801 - accuracy: 0.0164
# Epoch 3/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 14197.2832 - accuracy: 0.0000e+00
# Epoch 4/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 10991.8359 - accuracy: 0.0000e+00
# Epoch 5/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 10309.9424 - accuracy: 0.0000e+00
# Epoch 6/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 11492.0332 - accuracy: 0.0328
# Epoch 7/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 11460.2949 - accuracy: 0.0164
# Epoch 8/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 9503.5615 - accuracy: 0.0328
# Epoch 9/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 10088.3457 - accuracy: 0.0164
# Epoch 10/1000
# ...

# %%
X_train[0][0]

# %%
inputs
